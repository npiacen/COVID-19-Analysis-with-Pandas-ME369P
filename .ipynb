# %% [markdown]
# # Pandas Lightning Talk Demo
# By: Nick Piacente
# We will go over how to use pandas to import and process data from a csv

# %%
import pandas as pd

# %%
print('hello')
# Out:
# hello
